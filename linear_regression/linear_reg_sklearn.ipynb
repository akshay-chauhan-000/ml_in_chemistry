# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Generate random data points

# %%
eps = np.random.normal(loc=0.0, scale=5, size=50)
x = np.arange(start=-5, stop=5, step=0.2)
y = 2 + 3*x + eps
y1 = 2 + 3*x

df = pd.DataFrame(zip(x, y), columns=['x', 'y'])

# %% [markdown]
# # Visualize the data

# %%
plt.figure(figsize=(6,4))
plt.scatter(x, y, label='data', s=8, c='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Reshape x for sklearn
x = x.reshape(-1, 1)

# Fit the data using Linear regression
model = LinearRegression()
model.fit(x, y)

# Get the parameters
theta0 = model.intercept_
theta1 = model.coef_[0]

# Calculate predicted values
y_hat = model.predict(x)

# %% [markdown]
# # Visualize the fit

# %%
plt.figure(figsize=(6,4))
plt.scatter(x, y, label='data', s=8, c='blue')
plt.plot(x, y1, c='red', label='True y')
plt.plot(x, y_hat, c='green', label='Estimated y')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Calculate R-squared
r_squared = model.score(x, y)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.7761820966397984
